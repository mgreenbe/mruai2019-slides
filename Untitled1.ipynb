# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.inception_v3 import InceptionV3

from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from matplotlib import pyplot as plt

# %%
classes = [] 
with open("imagenet1000_clsidx_to_labels.txt", 'r') as f:
    for line in f:
        classes.append(line.replace(" ", "").replace("',\n", "").replace("'", "").replace(",", ", ").split(":")[1])

# %%
beagle = load_img("Beagle_600.jpg", target_size=(224, 224))
trilobite = load_img("Trilobite.jpg", target_size=(224, 224))
centipede = load_img("2560181040_3f0cf91f15.jpg", target_size=(224, 224))

ims = [beagle, trilobite, centipede]
x = np.stack([img_to_array(im) for im in ims], axis=0)
print(f"x.shape = {x.shape}")

fig, axes = plt.subplots(1, 3, figsize=(20, 20/3))
for (ax, im) in zip(axes, ims):
    ax.imshow(im)
# Out:
# x.shape = (3, 224, 224, 3)

# %%
mobilenet = MobileNetV2()
vgg16 = VGG16()
vgg19 = VGG19()
# Out:
# ...
# 574717952/574710816 [==============================] - 498s 1us/step

# %%
model = vgg19

y = model.predict(x).squeeze()
I = np.flip(np.argsort(y), axis=1)
print(np.array(classes)[I[:5]])
# Out:
# [['beagle' 'Walkerhound, Walkerfoxhound' 'Englishfoxhound' ...
#   'trilobite' 'freightcar' 'pomegranate']
#  ['isopod' 'trilobite' 'scorpion' ... 'entertainmentcenter'
#   'jaguar, panther, Pantheraonca, Felisonca' 'geyser']
#  ['seasnake' 'centipede' 'watersnake' ... 'sportscar, sportcar'
#   'basketball' 'scoreboard']]
